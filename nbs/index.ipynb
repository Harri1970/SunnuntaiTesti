# %%
#| hide
from SunnuntaiTesti.core import *

# %% [markdown]
# # SunnuntaiTesti
#
# > Testing only, first test from SolveIT

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install SunnuntaiTesti in Development mode

# %% [markdown]
# ```sh
# # make sure SunnuntaiTesti package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to SunnuntaiTesti
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/Harri1970/SunnuntaiTesti.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c Harri1970 SunnuntaiTesti
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install SunnuntaiTesti
# ```
#
#
# [repo]: https://github.com/Harri1970/SunnuntaiTesti
# [docs]: https://Harri1970.github.io/SunnuntaiTesti/
# [pypi]: https://pypi.org/project/SunnuntaiTesti/
# [conda]: https://anaconda.org/Harri1970/SunnuntaiTesti

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/Harri1970/SunnuntaiTesti
# [docs]: https://Harri1970.github.io/SunnuntaiTesti/
# [pypi]: https://pypi.org/project/SunnuntaiTesti/
# [conda]: https://anaconda.org/Harri1970/SunnuntaiTesti

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
