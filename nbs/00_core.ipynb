# %% [markdown]
# # core
#
# > Fill in a module description here

# %%
#| default_exp core

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(
    a:int #this is a
):
     "This passes"
     pass

# %% [markdown]
# This doesn't actually do nothing

# %%
#| hide
import nbdev; nbdev.nbdev_export()
